# %%
# %load_ext lab_black
# %load_ext autoreload

# %%
import pandas as pd
import numpy as np
import logging
import sys
import os
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append("\plz_functions")
from plz_functions import *

# os.getcwd()
logger = logging.getLogger()

# %%
berlin = pd.read_parquet(
    "C:/Users/sina_/Projects/OSM_Datenextrktion_Mapping/OSM_Berlin.parquet"
)
berlin
# Out:
#                          COMPANYNAME       AMENITY  \
# 0                 Berliner Volksbank          bank
# 1                      Deutsche Post   post_office
# 2            Bruno-Lösche-Bibliothek       library
# 3               Polizei Abschnitt 27        police
# 4                Sofort Sanierung 24          None
# ...                              ...           ...
# 14640  Evangelische Kita Heinersdorf  kindergarten
# 14641   Evangelische Kita Leuchtturm  kindergarten
# 14642           Sonnenkita Hermsdorf  kindergarten
# 14643             Kleine Nordlichter  kindergarten
# 14644                  Zwergenschloß  kindergarten
#
#                                                 OPERATOR               BRAND  \
# 0                                                   None  Berliner Volksbank
# 1                                          Deutsche Post       Deutsche Post
# 2                                                   None                None
# ...

# %%
berlin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14645 entries, 0 to 14644
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   COMPANYNAME  14645 non-null  object
#  1   AMENITY      5860 non-null   object
#  2   OPERATOR     4273 non-null   object
#  3   BRAND        2235 non-null   object
#  4   OFFICE       3140 non-null   object
#  5   SHOP         5679 non-null   object
#  6   CITY         14645 non-null  object
#  7   POSTALCODE   14645 non-null  object
#  8   STREET       14645 non-null  object
#  9   HSNR         14645 non-null  object
#  10  LAT          11672 non-null  float64
#  11  LON          11672 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 1.3+ MB

# %%
berlin.columns
# Out:
# Index(['COMPANYNAME', 'AMENITY', 'OPERATOR', 'BRAND', 'OFFICE', 'SHOP', 'CITY',
#        'POSTALCODE', 'STREET', 'HSNR', 'LAT', 'LON'],
#       dtype='object')

# %%
plz_check = plz_visual(berlin, "POSTALCODE")
plz_check
# Out:
# C:\Users\sina_\Projects\Address_cleaning\PLZ\plz_functions.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(patterns), palette=palette)

# %%
# Projects/Address_cleaning/companyDataClean.csv
df_hugging = pd.read_csv(
    "C:/Users/sina_/Projects/Address_cleaning/companyDataClean.csv"
)
df_hugging
# Out:
#                                              company  \
# 0                             Linde-KCA-Dresden GmbH
# 1                   Hagenuk KMT Kabelmeßtechnik GmbH
# 2       Bruno Söhnle GmbH Uhrenatelier Glashütte/Sa.
# 3                                    Funke & Will AG
# 4                  f6 Cigarettenfabrik GmbH & Co. KG
# ...                                              ...
# 260350      Friseursalon Avantgarde Rolf Schumm e.K.
# 260351                  BCN Bauconsult Nürnberg GmbH
# 260352    Autohaus Marienbergstraße Verwaltungs-GmbH
# 260353         Solalight Electronics M-Piruzram e.K.
# 260354                          ZAHR Immobilien GmbH
#
#                         "street"  "zip"       "city"
# 0                   Not provided  01277      Dresden
# 1                   Not provided  01471     Radeburg
# 2               Dresdner Str. 14  01768   Glashütte
# 3            Zum Fliegerhorst 11  01558  Großenhain
# 4                 Junghansstr. 5  01277      Dresden
# ...

# %%
plz_check = plz_visual(df_hugging, ' "zip"')
plz_check
# Out:
# C:\Users\sina_\Projects\Address_cleaning\PLZ\plz_functions.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=list(patterns), palette=palette)
